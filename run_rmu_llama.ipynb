# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# !python3 -m rmu.unlearn --model_name_or_path meta-llama/Llama-3.2-1B-Instruct --max_num_batches 150 --batch_size=4 --retain_corpora wikitext,wikitext --forget_corpora bio-forget-corpus,cyber-forget-corpus --steering_coeffs 6.5,6.5 --alpha 1200,1200 --lr 5e-5 --seed 42 --output_dir models/llama_rmu --verbose
